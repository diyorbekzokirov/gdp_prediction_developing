# %% [markdown]
# ### Import

# %%
import pandas as pd
import world_bank_data as wb
pd.set_option('display.max_rows', 6)

# %%
countries = wb.get_countries()
indicators = wb.get_indicators()

countries.head(10)
# Out:
#     iso2Code                         name  \
# id
# ABW       AW                        Aruba
# AFE       ZH  Africa Eastern and Southern
# AFG       AF                  Afghanistan
# ..       ...                          ...
# AND       AD                      Andorra
# ARB       1A                   Arab World
# ARE       AE         United Arab Emirates
#
#                                                 region  \
# id
# ABW                         Latin America & Caribbean
# AFE                                         Aggregates
# AFG  Middle East, North Africa, Afghanistan & Pakistan
# ..                                                 ...
# AND                              Europe & Central Asia
# ARB                                         Aggregates
# ARE  Middle East, North Africa, Afghanistan & Pakistan
#
#                                            adminregion  incomeLevel  \
# id
# ABW                                                     High income
# ...

# %%
countries['incomeLevel'].value_counts()
# Out:
# incomeLevel
# High income            86
# Aggregates             79
# Upper middle income    54
# Lower middle income    50
# Low income             25
# Not classified          2
# Name: count, dtype: int64

# %%
developing = countries[countries['incomeLevel'].isin(['Low income', 'Lower middle income', 'Upper middle income'])]
developing.head(5)
# Out:
#     iso2Code         name                                             region  \
# id
# AFG       AF  Afghanistan  Middle East, North Africa, Afghanistan & Pakistan
# AGO       AO       Angola                                Sub-Saharan Africa
# ALB       AL      Albania                              Europe & Central Asia
# ARG       AR    Argentina                         Latin America & Caribbean
# ARM       AM      Armenia                              Europe & Central Asia
#
#                                            adminregion          incomeLevel  \
# id
# AFG  Middle East, North Africa, Afghanistan & Pakis...           Low income
# AGO         Sub-Saharan Africa (excluding high income)  Lower middle income
# ALB      Europe & Central Asia (excluding high income)  Upper middle income
# ARG  Latin America & Caribbean (excluding high income)  Upper middle income
# ARM      Europe & Central Asia (excluding high income)  Upper middle income
#
# ...
