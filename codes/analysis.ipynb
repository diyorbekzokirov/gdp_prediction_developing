# %%
import pandas as pd
import wbgapi as wb

# %% [markdown]
# ### WB source info

# %%
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2025-10-07
# 3     Worldwide Governance Indicators                                       WGI              3  2024-11-05
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2025-02-26
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2024-06-25
# ...

# %%
wb.income.info()   # income groups
# Out:
# id    value
# ----  -------------------
# HIC   High income
# INX   Not classified
# LIC   Low income
# LMC   Lower middle income
# LMY   Low & middle income
# MIC   Middle income
# UMC   Upper middle income
#       7 elements

# %%
developing = ['LIC', 'LMC', 'LMY'] # define the developing country groups

# %%
wb.data.DataFrame(['SP.POP.TOTL', 'NY.GDP.PCAP.CD'],
                  developing, range(2010, 2015))
# Out:
#                               YR2010        YR2011        YR2012  \
# economy series
# LIC     NY.GDP.PCAP.CD  8.205629e+02  8.685304e+02  7.724480e+02
#         SP.POP.TOTL     4.295156e+08  4.416588e+08  4.536529e+08
# LMC     NY.GDP.PCAP.CD  1.486733e+03  1.631114e+03  1.695304e+03
#         SP.POP.TOTL     2.550265e+09  2.593815e+09  2.637101e+09
# LMY     NY.GDP.PCAP.CD  3.390750e+03  3.939152e+03  4.130064e+03
#         SP.POP.TOTL     5.553258e+09  5.630227e+09  5.709188e+09
#
#                               YR2013        YR2014
# economy series
# LIC     NY.GDP.PCAP.CD  7.675444e+02  7.892845e+02
#         SP.POP.TOTL     4.650879e+08  4.764708e+08
# LMC     NY.GDP.PCAP.CD  1.763789e+03  1.874775e+03
#         SP.POP.TOTL     2.679816e+09  2.723062e+09
# LMY     NY.GDP.PCAP.CD  4.326215e+03  4.468797e+03
#         SP.POP.TOTL     5.787470e+09  5.865317e+09

# %%
df = wb.data.DataFrame('EG.ELC.ACCS.ZS', developing, time=range(1990,1996))
df
# Out:
#          YR1990  YR1991  YR1992     YR1993     YR1994    YR1995
# economy
# LIC         NaN     NaN     NaN        NaN        NaN       NaN
# LMC         NaN     NaN     NaN  47.148194  47.108639  48.34385
# LMY         NaN     NaN     NaN        NaN        NaN       NaN

# %%
print(wb.economy.info())
# Out:
# id    value                                                                      region    incomeLevel
# ----  -------------------------------------------------------------------------  --------  -------------
# ABW   Aruba                                                                      LCN       HIC
# AFE   Africa Eastern and Southern
# AFG   Afghanistan                                                                MEA       LIC
# AFW   Africa Western and Central
# AGO   Angola                                                                     SSF       LMC
# ALB   Albania                                                                    ECS       UMC
# AND   Andorra                                                                    ECS       HIC
# ARB   Arab World
# ARE   United Arab Emirates                                                       MEA       HIC
# ARG   Argentina                                                                  LCN       UMC
# ...

# %%
df1 = pd.read_csv('/home/diyorbek/Documents/world_bank_data/7cb95033-6c85-493c-bba6-5fb1561ad8f5_Data.csv')
df1
# Out:
#                                           Country Name Country Code  \
# 0                                           Low income          LIC
# 1                                           Low income          LIC
# 2                                           Low income          LIC
# 3                                           Low income          LIC
# 4                                           Low income          LIC
# ...                                                ...          ...
# 1086                                               NaN          NaN
# 1087                                               NaN          NaN
# 1088                                               NaN          NaN
# 1089  Data from database: World Development Indicators          NaN
# 1090                          Last Updated: 10/07/2025          NaN
#
#                                             Series Name        Series Code  \
# ...
